# %%
# First, load data from CATAR files in the database
from pathlib import Path
data_folder = Path("/Users/persie/PycharmProjects/prolley-parnell/ant-grasp-dataset")
catar_folder = data_folder / "dataset" / "Annotation" / "catar"
catar_file = catar_folder / "240905-1616" / "240905-1616_session19-2d_points_catar.csv"

# %%
class TwoDPoints :
    def __init__(self) :
        pass

# %%
#file type is .csv

import numpy as np
np.loadtxt(catar_file, delimiter=",", skiprows=1, dtype=str)
